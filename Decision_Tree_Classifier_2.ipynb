# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer()
df["fever"]=si.fit_transform(df[["fever"]])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["gender"]=le.fit_transform(df["gender"])
df["cough"]=le.fit_transform(df["cough"])
df["city"]=le.fit_transform(df["city"])
df["has_covid"]=le.fit_transform(df["has_covid"])

# %%
df.head(3)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0

# %%
x=df.drop(columns="has_covid")
y=df["has_covid"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.45

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[5, 8],
#        [3, 4]], dtype=int64)

# %%
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)
# Out:
# 0.3333333333333333

# %%
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)
# Out:
# 0.5714285714285714

# %%
#Question: How can we avoid overfitting in Decision Tree Classifier model
# How can we decide how many numbers of child node will be there in the decision tree algorithm
