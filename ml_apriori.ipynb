# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("market_basket.csv", header = None)
df.head(3)
# Out:
#         0          1        2               3             4   \
# 0   shrimp    almonds  avocado  vegetables mix  green grapes
# 1  burgers  meatballs     eggs             NaN           NaN
# 2  chutney        NaN      NaN             NaN           NaN
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5976 sha256=af5e5a7d9b8d178c2ff13194c77eb64b70bd8538d55203a7bf937c51d11786e9
#   Stored in directory: c:\users\shaba\appdata\local\pip\cache\wheels\7f\49\e3\42c73b19a264de37129fadaa0c52f26cf50e87de08fb9804af
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
#Data Processing
transactions= []
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range (0,20)])

#Training the dataset
from apyori import apriori
rules= apriori(transactions,
              min_support=0.003,
              min_confidence=0.2,
              min_left=3,
              min_length=2)

#Visualizing the result
a=list(rules)
result=[list(a[i][0]) for i in range(0, len(a))]

# %%
a
# Out:
# [RelationRecord(items=frozenset({'mineral water'}), support=0.23836821757099053, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water'}), confidence=0.23836821757099053, lift=1.0)]),
#  RelationRecord(items=frozenset({'nan'}), support=0.9998666844420744, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9998666844420744, lift=1.0)]),
#  RelationRecord(items=frozenset({'burgers', 'almonds'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]),
#  RelationRecord(items=frozenset({'almonds', 'chocolate'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'chocolate'}), confidence=0.29411764705882354, lift=1.7950988369310295)]),
#  RelationRecord(items=frozenset({'almonds', 'eggs'}), support=0.006532462338354886, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'eggs'}), confidence=0.3202614379084967, lift=1.7821076007059597)]),
#  RelationRecord(items=frozenset({'almonds', 'french fries'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'french fries'}), confidence=0.21568627450980393, lift=1.2619834205132914)]),
#  RelationRecord(items=frozenset({'almonds', 'green tea'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'green tea'}), confidence=0.24836601307189543, lift=1.879912678155689)]),
#  RelationRecord(items=frozenset({'almonds', 'milk'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'milk'}), confidence=0.25490196078431376, lift=1.9670983619785367)]),
#  RelationRecord(items=frozenset({'almonds', 'mineral water'}), support=0.007598986801759766, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'mineral water'}), confidence=0.37254901960784315, lift=1.5629139799096374)]),
#  RelationRecord(items=frozenset({'nan', 'almonds'}), support=0.020263964804692707, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'nan'}), confidence=0.9934640522875817, lift=0.9935965141612201)]),
#  RelationRecord(items=frozenset({'spaghetti', 'almonds'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'spaghetti'}), confidence=0.29411764705882354, lift=1.6892622286280516)]),
#  RelationRecord(items=frozenset({'nan', 'antioxydant juice'}), support=0.008798826823090255, ordered_statistics=[OrderedStatistic(items_base=frozenset({'antioxydant juice'}), items_add=frozenset({'nan'}), confidence=0.9850746268656716, lift=0.9852059701492537)]),
#  RelationRecord(items=frozenset({'nan', 'asparagus'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'asparagus'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'avocado', 'chocolate'}), support=0.007065724570057326, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'chocolate'}), confidence=0.212, lift=1.293907241659886)]),
#  RelationRecord(items=frozenset({'avocado', 'french fries'}), support=0.007998933475536596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'french fries'}), confidence=0.24000000000000002, lift=1.4042433697347896)]),
#  RelationRecord(items=frozenset({'milk', 'avocado'}), support=0.007465671243834155, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'milk'}), confidence=0.22399999999999998, lift=1.728625514403292)]),
#  RelationRecord(items=frozenset({'avocado', 'mineral water'}), support=0.011598453539528063, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'mineral water'}), confidence=0.348, lift=1.4599261744966443)]),
#  RelationRecord(items=frozenset({'nan', 'avocado'}), support=0.03319557392347687, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'nan'}), confidence=0.996, lift=0.9961328)]),
#  RelationRecord(items=frozenset({'spaghetti', 'avocado'}), support=0.007998933475536596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'spaghetti'}), confidence=0.24000000000000002, lift=1.37843797856049)]),
#  RelationRecord(items=frozenset({'nan', 'babies food'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'babies food'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'bacon', 'mineral water'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'mineral water'}), confidence=0.35384615384615387, lift=1.4844519015659956)]),
#  RelationRecord(items=frozenset({'bacon', 'nan'}), support=0.008665511265164644, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'bacon', 'spaghetti'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'spaghetti'}), confidence=0.36923076923076925, lift=2.1206738131699847)]),
#  RelationRecord(items=frozenset({'eggs', 'barbecue sauce'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'barbecue sauce'}), items_add=frozenset({'eggs'}), confidence=0.3333333333333333, lift=1.8548466864490603)]),
#  RelationRecord(items=frozenset({'barbecue sauce', 'mineral water'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'barbecue sauce'}), items_add=frozenset({'mineral water'}), confidence=0.35802469135802467, lift=1.501981661004778)]),
#  RelationRecord(items=frozenset({'nan', 'barbecue sauce'}), support=0.010798560191974404, ordered_statistics=[OrderedStatistic(items_base=frozenset({'barbecue sauce'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'black tea', 'eggs'}), support=0.004932675643247567, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'eggs'}), confidence=0.34579439252336447, lift=1.924186749493885)]),
#  RelationRecord(items=frozenset({'black tea', 'milk'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'milk'}), confidence=0.29906542056074764, lift=2.3079112341833006)]),
#  RelationRecord(items=frozenset({'black tea', 'mineral water'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'mineral water'}), confidence=0.37383177570093457, lift=1.5682953856446926)]),
#  RelationRecord(items=frozenset({'nan', 'black tea'}), support=0.014264764698040262, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'black tea'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'spaghetti'}), confidence=0.3177570093457944, lift=1.8250347068168482)]),
#  RelationRecord(items=frozenset({'blueberries', 'mineral water'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'blueberries'}), items_add=frozenset({'mineral water'}), confidence=0.3913043478260869, lift=1.6415961482346075)]),
#  RelationRecord(items=frozenset({'nan', 'blueberries'}), support=0.009198773496867084, ordered_statistics=[OrderedStatistic(items_base=frozenset({'blueberries'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'blueberries'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'blueberries'}), items_add=frozenset({'spaghetti'}), confidence=0.37681159420289856, lift=2.164214217546663)]),
#  RelationRecord(items=frozenset({'body spray', 'french fries'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'body spray'}), items_add=frozenset({'french fries'}), confidence=0.37209302325581395, lift=2.17712150346479)]),
#  RelationRecord(items=frozenset({'body spray', 'mineral water'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'body spray'}), items_add=frozenset({'mineral water'}), confidence=0.3604651162790698, lift=1.5122197076114667)]),
#  RelationRecord(items=frozenset({'nan', 'body spray'}), support=0.011465137981602452, ordered_statistics=[OrderedStatistic(items_base=frozenset({'body spray'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'brownies'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'eggs'}), confidence=0.21739130434782608, lift=1.2096826215972132)]),
#  RelationRecord(items=frozenset({'brownies', 'french fries'}), support=0.007865617917610986, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'french fries'}), confidence=0.23320158102766797, lift=1.3644657248740544)]),
#  RelationRecord(items=frozenset({'mineral water', 'brownies'}), support=0.009598720170643914, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'mineral water'}), confidence=0.2845849802371541, lift=1.1938881078069872)]),
#  RelationRecord(items=frozenset({'nan', 'brownies'}), support=0.03372883615517931, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'brownies'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'spaghetti'}), confidence=0.21739130434782608, lift=1.2485851255076903)]),
#  RelationRecord(items=frozenset({'bug spray', 'nan'}), support=0.008665511265164644, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bug spray'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'nan', 'burger sauce'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burger sauce'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'burgers', 'eggs'}), support=0.02879616051193174, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'eggs'}), confidence=0.33027522935779813, lift=1.8378297443715457)]),
#  RelationRecord(items=frozenset({'burgers', 'french fries'}), support=0.021997067057725635, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'french fries'}), confidence=0.25229357798165136, lift=1.4761732671141707)]),
#  RelationRecord(items=frozenset({'burgers', 'green tea'}), support=0.0174643380882549, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'green tea'}), confidence=0.2003058103975535, lift=1.5161391360161947)]),
#  RelationRecord(items=frozenset({'burgers', 'ham'}), support=0.005599253432875617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'burgers'}), confidence=0.21105527638190955, lift=2.420681388594348)]),
#  RelationRecord(items=frozenset({'burgers', 'milk'}), support=0.01786428476203173, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'milk'}), confidence=0.20489296636085627, lift=1.581175041844427)]),
#  RelationRecord(items=frozenset({'burgers', 'mineral water'}), support=0.024396747100386616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'mineral water'}), confidence=0.2798165137614679, lift=1.1738834841861134)]),
#  RelationRecord(items=frozenset({'burgers', 'nan'}), support=0.0871883748833489, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'burgers'}), support=0.021463804826023197, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'spaghetti'}), confidence=0.24617737003058102, lift=1.4139176513012162)]),
#  RelationRecord(items=frozenset({'butter', 'chocolate'}), support=0.008265564591387815, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'chocolate'}), confidence=0.2743362831858407, lift=1.674366525774606)]),
#  RelationRecord(items=frozenset({'butter', 'eggs'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'eggs'}), confidence=0.20353982300884957, lift=1.1326054988051786)]),
#  RelationRecord(items=frozenset({'butter', 'french fries'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'french fries'}), confidence=0.20353982300884957, lift=1.1909143622382066)]),
#  RelationRecord(items=frozenset({'butter', 'green tea'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'green tea'}), confidence=0.2433628318584071, lift=1.842042988667923)]),
#  RelationRecord(items=frozenset({'butter', 'milk'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'milk'}), confidence=0.20353982300884957, lift=1.5707327287956592)]),
#  RelationRecord(items=frozenset({'nan', 'butter'}), support=0.030129316091187842, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'butter'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'spaghetti'}), confidence=0.2079646017699115, lift=1.1944429386493922)]),
#  RelationRecord(items=frozenset({'cake', 'eggs'}), support=0.019064124783362217, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'eggs'}), confidence=0.23519736842105263, lift=1.308765178431985)]),
#  RelationRecord(items=frozenset({'cake', 'french fries'}), support=0.01786428476203173, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'french fries'}), confidence=0.22039473684210528, lift=1.289532699729042)]),
#  RelationRecord(items=frozenset({'cake', 'mineral water'}), support=0.027463004932675644, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'mineral water'}), confidence=0.33881578947368424, lift=1.4213966649005065)]),
#  RelationRecord(items=frozenset({'nan', 'cake'}), support=0.08105585921877083, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'cake'}), support=0.018130915877882948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'spaghetti'}), confidence=0.2236842105263158, lift=1.2847283791408077)]),
#  RelationRecord(items=frozenset({'nan', 'candy bars'}), support=0.009732035728569524, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candy bars'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'chocolate', 'carrots'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'chocolate'}), confidence=0.22608695652173913, lift=1.3798846711713304)]),
#  RelationRecord(items=frozenset({'green tea', 'carrots'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'green tea'}), confidence=0.23478260869565218, lift=1.7770982319133068)]),
#  RelationRecord(items=frozenset({'mineral water', 'carrots'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'mineral water'}), confidence=0.34782608695652173, lift=1.45919657620854)]),
#  RelationRecord(items=frozenset({'nan', 'carrots'}), support=0.01533128916144514, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'carrots'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'spaghetti'}), confidence=0.30434782608695654, lift=1.7480191757107666)]),
#  RelationRecord(items=frozenset({'nan', 'cauliflower'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cauliflower'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cereals', 'chocolate'}), support=0.005599253432875617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'chocolate'}), confidence=0.21761658031088085, lift=1.3281871187240986)]),
#  RelationRecord(items=frozenset({'cereals', 'green tea'}), support=0.006532462338354886, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'green tea'}), confidence=0.2538860103626943, lift=1.9216942116352878)]),
#  RelationRecord(items=frozenset({'cereals', 'milk'}), support=0.007065724570057326, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'milk'}), confidence=0.2746113989637306, lift=2.119197637476279)]),
#  RelationRecord(items=frozenset({'cereals', 'mineral water'}), support=0.010265297960271964, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'mineral water'}), confidence=0.3989637305699482, lift=1.6737287153272828)]),
#  RelationRecord(items=frozenset({'cereals', 'nan'}), support=0.025729902679642713, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cereals', 'spaghetti'}), support=0.006665777896280496, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'spaghetti'}), confidence=0.2590673575129534, lift=1.4879511858381802)]),
#  RelationRecord(items=frozenset({'champagne', 'chocolate'}), support=0.011598453539528063, ordered_statistics=[OrderedStatistic(items_base=frozenset({'champagne'}), items_add=frozenset({'chocolate'}), confidence=0.24786324786324784, lift=1.5127926950546964)]),
#  RelationRecord(items=frozenset({'champagne', 'nan'}), support=0.04679376083188908, ordered_statistics=[OrderedStatistic(items_base=frozenset({'champagne'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'chicken', 'chocolate'}), support=0.014664711371817091, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'chocolate'}), confidence=0.24444444444444446, lift=1.4919265889160112)]),
#  RelationRecord(items=frozenset({'eggs', 'chicken'}), support=0.01439808025596587, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'eggs'}), confidence=0.24, lift=1.3354896142433235)]),
#  RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'milk', 'chicken'}), support=0.014798026929742702, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'milk'}), confidence=0.24666666666666667, lift=1.9035459533607684)]),
#  RelationRecord(items=frozenset({'chicken', 'mineral water'}), support=0.022796960405279298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'mineral water'}), confidence=0.38000000000000006, lift=1.5941722595078303)]),
#  RelationRecord(items=frozenset({'nan', 'chicken'}), support=0.05999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'chicken'}), support=0.01719770697240368, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'spaghetti'}), confidence=0.2866666666666667, lift=1.6464675855028077)]),
#  RelationRecord(items=frozenset({'nan', 'chili'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chili'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cooking oil', 'chocolate'}), support=0.013598186908412212, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'chocolate'}), confidence=0.26631853785900783, lift=1.6254315317171828)]),
#  RelationRecord(items=frozenset({'eggs', 'chocolate'}), support=0.03319557392347687, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'eggs'}), confidence=0.20260374288039054, lift=1.1273966434316094)]),
#  RelationRecord(items=frozenset({'escalope', 'chocolate'}), support=0.01759765364618051, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'chocolate'}), confidence=0.22184873949579834, lift=1.3540174084279766)]),
#  RelationRecord(items=frozenset({'chocolate', 'french fries'}), support=0.03439541394480736, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'french fries'}), confidence=0.209926769731489, lift=1.2282844771886887), OrderedStatistic(items_base=frozenset({'french fries'}), items_add=frozenset({'chocolate'}), confidence=0.20124804992199688, lift=1.2282844771886887)]),
#  RelationRecord(items=frozenset({'chocolate', 'french wine'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'french wine'}), items_add=frozenset({'chocolate'}), confidence=0.23076923076923078, lift=1.4084621643612694)]),
#  RelationRecord(items=frozenset({'fresh bread', 'chocolate'}), support=0.009465404612718305, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh bread'}), items_add=frozenset({'chocolate'}), confidence=0.21981424148606812, lift=1.3416001833905589)]),
#  RelationRecord(items=frozenset({'fresh tuna', 'chocolate'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh tuna'}), items_add=frozenset({'chocolate'}), confidence=0.2155688622754491, lift=1.3156892074272935)]),
#  RelationRecord(items=frozenset({'fromage blanc', 'chocolate'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'chocolate'}), confidence=0.22549019607843138, lift=1.3762424416471226)]),
#  RelationRecord(items=frozenset({'frozen smoothie', 'chocolate'}), support=0.01493134248766831, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen smoothie'}), items_add=frozenset({'chocolate'}), confidence=0.23578947368421052, lift=1.43910239390176)]),
#  RelationRecord(items=frozenset({'frozen vegetables', 'chocolate'}), support=0.022930275963204905, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'chocolate'}), confidence=0.24055944055944053, lift=1.4682151046675047)]),
#  RelationRecord(items=frozenset({'grated cheese', 'chocolate'}), support=0.010931875749900012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'grated cheese'}), items_add=frozenset({'chocolate'}), confidence=0.20865139949109412, lift=1.2734696074716818)]),
#  RelationRecord(items=frozenset({'ground beef', 'chocolate'}), support=0.023063591521130515, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'chocolate'}), confidence=0.23473541383989144, lift=1.4326691124597442)]),
#  RelationRecord(items=frozenset({'ham', 'chocolate'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'chocolate'}), confidence=0.23618090452261306, lift=1.441491427847128)]),
#  RelationRecord(items=frozenset({'light cream', 'chocolate'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chocolate'}), confidence=0.23076923076923075, lift=1.4084621643612691)]),
#  RelationRecord(items=frozenset({'milk', 'chocolate'}), support=0.03212904946007199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk'}), items_add=frozenset({'chocolate'}), confidence=0.2479423868312757, lift=1.5132757067708698)]),
#  RelationRecord(items=frozenset({'chocolate', 'mineral water'}), support=0.05265964538061592, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'mineral water'}), confidence=0.3213995117982099, lift=1.3483320682317521), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'chocolate'}), confidence=0.220917225950783, lift=1.348332068231752)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'chocolate'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'chocolate'}), confidence=0.23076923076923078, lift=1.4084621643612694)]),
#  RelationRecord(items=frozenset({'nan', 'chocolate'}), support=0.1638448206905746, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'chocolate', 'oil'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'chocolate'}), confidence=0.26589595375722547, lift=1.6228523589364916)]),
#  RelationRecord(items=frozenset({'olive oil', 'chocolate'}), support=0.01639781362485002, ordered_statistics=[OrderedStatistic(items_base=frozenset({'olive oil'}), items_add=frozenset({'chocolate'}), confidence=0.24898785425101214, lift=1.5196565457582114)]),
#  RelationRecord(items=frozenset({'pancakes', 'chocolate'}), support=0.01986401813091588, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes'}), items_add=frozenset({'chocolate'}), confidence=0.20897615708274897, lift=1.2754517121868998)]),
#  RelationRecord(items=frozenset({'parmesan cheese', 'chocolate'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'parmesan cheese'}), items_add=frozenset({'chocolate'}), confidence=0.2147651006711409, lift=1.3107835802556778)]),
#  RelationRecord(items=frozenset({'chocolate', 'pepper'}), support=0.006399146780429276, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pepper'}), items_add=frozenset({'chocolate'}), confidence=0.24120603015075376, lift=1.4721614582268543)]),
#  RelationRecord(items=frozenset({'rice', 'chocolate'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rice'}), items_add=frozenset({'chocolate'}), confidence=0.2836879432624113, lift=1.7314428498058154)]),
#  RelationRecord(items=frozenset({'salmon', 'chocolate'}), support=0.010665244634048793, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salmon'}), items_add=frozenset({'chocolate'}), confidence=0.2507836990595611, lift=1.5306171901104701)]),
#  RelationRecord(items=frozenset({'shrimp', 'chocolate'}), support=0.017997600319957337, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shrimp'}), items_add=frozenset({'chocolate'}), confidence=0.251865671641791, lift=1.5372208323719074)]),
#  RelationRecord(items=frozenset({'soup', 'chocolate'}), support=0.010131982402346354, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soup'}), items_add=frozenset({'chocolate'}), confidence=0.20052770448548812, lift=1.2238879669207863)]),
#  RelationRecord(items=frozenset({'spaghetti', 'chocolate'}), support=0.03919477403012932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'spaghetti'}), confidence=0.23921887713588283, lift=1.3739516059695691), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'chocolate'}), confidence=0.22511485451761104, lift=1.3739516059695691)]),
#  RelationRecord(items=frozenset({'tomato sauce', 'chocolate'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomato sauce'}), items_add=frozenset({'chocolate'}), confidence=0.3584905660377358, lift=2.1879883936932925)]),
#  RelationRecord(items=frozenset({'chocolate', 'tomatoes'}), support=0.013998133582189041, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomatoes'}), items_add=frozenset({'chocolate'}), confidence=0.2046783625730994, lift=1.2492208280397221)]),
#  RelationRecord(items=frozenset({'chocolate', 'white wine'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white wine'}), items_add=frozenset({'chocolate'}), confidence=0.2096774193548387, lift=1.27973175148954)]),
#  RelationRecord(items=frozenset({'whole wheat pasta', 'chocolate'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat pasta'}), items_add=frozenset({'chocolate'}), confidence=0.21266968325791855, lift=1.297994543627052)]),
#  RelationRecord(items=frozenset({'whole wheat rice', 'chocolate'}), support=0.011998400213304892, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat rice'}), items_add=frozenset({'chocolate'}), confidence=0.20501138952164008, lift=1.2512534034188951)]),
#  RelationRecord(items=frozenset({'chocolate bread', 'nan'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate bread'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'chutney', 'nan'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chutney'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cider', 'eggs'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cider'}), items_add=frozenset({'eggs'}), confidence=0.4050632911392405, lift=2.2539909101153137)]),
#  RelationRecord(items=frozenset({'cider', 'milk'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cider'}), items_add=frozenset({'milk'}), confidence=0.31645569620253167, lift=2.4421133510444344)]),
#  RelationRecord(items=frozenset({'nan', 'cider'}), support=0.010531929076123183, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cider'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'clothes accessories', 'nan'}), support=0.008398880149313425, ordered_statistics=[OrderedStatistic(items_base=frozenset({'clothes accessories'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'nan', 'cookies'}), support=0.08038928142914278, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cookies'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cooking oil', 'eggs'}), support=0.011731769097453673, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'eggs'}), confidence=0.2297650130548303, lift=1.2785366193800312)]),
#  RelationRecord(items=frozenset({'cooking oil', 'milk'}), support=0.011465137981602452, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'milk'}), confidence=0.22454308093994776, lift=1.732816512479988)]),
#  RelationRecord(items=frozenset({'cooking oil', 'mineral water'}), support=0.020130649246767097, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'mineral water'}), confidence=0.3942558746736292, lift=1.6539783646123563)]),
#  RelationRecord(items=frozenset({'cooking oil', 'nan'}), support=0.0510598586855086, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'cooking oil'}), support=0.01586455139314758, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'spaghetti'}), confidence=0.31070496083550914, lift=1.7845313255950643)]),
#  RelationRecord(items=frozenset({'nan', 'corn'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'corn'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'green tea', 'cottage cheese'}), support=0.006399146780429276, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'green tea'}), confidence=0.200836820083682, lift=1.5201584131661945)]),
#  RelationRecord(items=frozenset({'cottage cheese', 'mineral water'}), support=0.009598720170643914, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'mineral water'}), confidence=0.30125523012552297, lift=1.263822976046727)]),
#  RelationRecord(items=frozenset({'nan', 'cottage cheese'}), support=0.03172910278629516, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'nan'}), confidence=0.9958158995815899, lift=0.9959486750348674)]),
#  RelationRecord(items=frozenset({'spaghetti', 'cottage cheese'}), support=0.006932409012131715, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'spaghetti'}), confidence=0.21757322175732213, lift=1.2496299666169015)]),
#  RelationRecord(items=frozenset({'dessert wine', 'nan'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dessert wine'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'eggplant'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggplant'}), items_add=frozenset({'eggs'}), confidence=0.2727272727272727, lift=1.517601834367413)]),
#  RelationRecord(items=frozenset({'eggplant', 'mineral water'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggplant'}), items_add=frozenset({'mineral water'}), confidence=0.2828282828282828, lift=1.1865184281291663)]),
#  RelationRecord(items=frozenset({'nan', 'eggplant'}), support=0.013198240234635382, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggplant'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'eggplant'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggplant'}), items_add=frozenset({'spaghetti'}), confidence=0.29292929292929293, lift=1.6824369266942008)]),
#  RelationRecord(items=frozenset({'eggs', 'french fries'}), support=0.036395147313691506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'french fries'}), confidence=0.20252225519287834, lift=1.1849605586597352), OrderedStatistic(items_base=frozenset({'french fries'}), items_add=frozenset({'eggs'}), confidence=0.21294851794071765, lift=1.1849605586597352)]),
#  RelationRecord(items=frozenset({'eggs', 'french wine'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'french wine'}), items_add=frozenset({'eggs'}), confidence=0.2662721893491124, lift=1.4816822643232137)]),
#  RelationRecord(items=frozenset({'fresh bread', 'eggs'}), support=0.008665511265164644, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh bread'}), items_add=frozenset({'eggs'}), confidence=0.20123839009287925, lift=1.1197990831503615)]),
#  RelationRecord(items=frozenset({'eggs', 'fresh tuna'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh tuna'}), items_add=frozenset({'eggs'}), confidence=0.2634730538922156, lift=1.4661063629417723)]),
#  RelationRecord(items=frozenset({'eggs', 'fromage blanc'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'eggs'}), confidence=0.29411764705882354, lift=1.6366294292197592)]),
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables'}), support=0.021730435941874418, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.22797202797202798, lift=1.2685594820609658)]),
#  RelationRecord(items=frozenset({'ground beef', 'eggs'}), support=0.019997333688841486, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'eggs'}), confidence=0.20352781546811397, lift=1.132538682363741)]),
#  RelationRecord(items=frozenset({'ham', 'eggs'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'eggs'}), confidence=0.23618090452261306, lift=1.3142381044689322)]),
#  RelationRecord(items=frozenset({'herb & pepper', 'eggs'}), support=0.012531662445007332, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.25336927223719674, lift=1.4098834651715229)]),
#  RelationRecord(items=frozenset({'light cream', 'eggs'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'eggs'}), confidence=0.2136752136752137, lift=1.1890042861852952)]),
#  RelationRecord(items=frozenset({'eggs', 'light mayo'}), support=0.005465937874950006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light mayo'}), items_add=frozenset({'eggs'}), confidence=0.20098039215686272, lift=1.1183634433001686)]),
#  RelationRecord(items=frozenset({'low fat yogurt', 'eggs'}), support=0.01679776029862685, ordered_statistics=[OrderedStatistic(items_base=frozenset({'low fat yogurt'}), items_add=frozenset({'eggs'}), confidence=0.21951219512195125, lift=1.2214844032713326)]),
#  RelationRecord(items=frozenset({'meatballs', 'eggs'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meatballs'}), items_add=frozenset({'eggs'}), confidence=0.21019108280254778, lift=1.1696167003723374)]),
#  RelationRecord(items=frozenset({'milk', 'eggs'}), support=0.03079589388081589, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk'}), items_add=frozenset({'eggs'}), confidence=0.23765432098765432, lift=1.322436989412756)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water'}), support=0.05092654312758299, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.28338278931750743, lift=1.188844688294532), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.21364653243847875, lift=1.188844688294532)]),
#  RelationRecord(items=frozenset({'nan', 'eggs'}), support=0.17970937208372217, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'pancakes', 'eggs'}), support=0.021730435941874418, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes'}), items_add=frozenset({'eggs'}), confidence=0.2286115007012623, lift=1.2721178536796502)]),
#  RelationRecord(items=frozenset({'parmesan cheese', 'eggs'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'parmesan cheese'}), items_add=frozenset({'eggs'}), confidence=0.22818791946308722, lift=1.269760818911437)]),
#  RelationRecord(items=frozenset({'red wine', 'eggs'}), support=0.007065724570057326, ordered_statistics=[OrderedStatistic(items_base=frozenset({'red wine'}), items_add=frozenset({'eggs'}), confidence=0.25118483412322273, lift=1.3977280717791496)]),
#  RelationRecord(items=frozenset({'spaghetti', 'eggs'}), support=0.036528462871617116, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'spaghetti'}), confidence=0.2032640949554896, lift=1.1674456173515526), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'eggs'}), confidence=0.20980091883614088, lift=1.1674456173515524)]),
#  RelationRecord(items=frozenset({'eggs', 'turkey'}), support=0.01946407145713905, ordered_statistics=[OrderedStatistic(items_base=frozenset({'turkey'}), items_add=frozenset({'eggs'}), confidence=0.31130063965884863, lift=1.7322448798820649)]),
#  RelationRecord(items=frozenset({'milk', 'energy bar'}), support=0.005465937874950006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy bar'}), items_add=frozenset({'milk'}), confidence=0.20197044334975367, lift=1.5586217032577185)]),
#  RelationRecord(items=frozenset({'mineral water', 'energy bar'}), support=0.006799093454206106, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy bar'}), items_add=frozenset({'mineral water'}), confidence=0.2512315270935961, lift=1.0539640294905281)]),
#  RelationRecord(items=frozenset({'nan', 'energy bar'}), support=0.027063058258898813, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy bar'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'energy drink', 'french fries'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy drink'}), items_add=frozenset({'french fries'}), confidence=0.22999999999999998, lift=1.3457332293291733)]),
#  RelationRecord(items=frozenset({'mineral water', 'energy drink'}), support=0.005599253432875617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy drink'}), items_add=frozenset({'mineral water'}), confidence=0.21, lift=0.880989932885906)]),
#  RelationRecord(items=frozenset({'nan', 'energy drink'}), support=0.026529796027196375, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy drink'}), items_add=frozenset({'nan'}), confidence=0.995, lift=0.9951326666666667)]),
#  RelationRecord(items=frozenset({'escalope', 'french fries'}), support=0.01639781362485002, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'french fries'}), confidence=0.20672268907563024, lift=1.2095373562841674)]),
#  RelationRecord(items=frozenset({'escalope', 'mineral water'}), support=0.017064391414478068, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'mineral water'}), confidence=0.21512605042016805, lift=0.9024946891508281)]),
#  RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'nan'}), support=0.0793227569657379, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
#  RelationRecord(items=frozenset({'mineral water', 'extra dark chocolate'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'extra dark chocolate'}), items_add=frozenset({'mineral water'}), confidence=0.47777777777777775, lift=2.0043686303753416)]),
#  RelationRecord(items=frozenset({'nan', 'extra dark chocolate'}), support=0.011998400213304892, ordered_statistics=[OrderedStatistic(items_base=frozenset({'extra dark chocolate'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'extra dark chocolate'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'extra dark chocolate'}), items_add=frozenset({'spaghetti'}), confidence=0.34444444444444444, lift=1.9783137655266292)]),
#  RelationRecord(items=frozenset({'flax seed', 'green tea'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flax seed'}), items_add=frozenset({'green tea'}), confidence=0.3382352941176471, lift=2.560144239330445)]),
#  RelationRecord(items=frozenset({'nan', 'flax seed'}), support=0.009065457938941474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flax seed'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'fromage blanc', 'french fries'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'french fries'}), confidence=0.2745098039215686, lift=1.6061607170169159)]),
#  RelationRecord(items=frozenset({'frozen smoothie', 'french fries'}), support=0.014531395813891481, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen smoothie'}), items_add=frozenset({'french fries'}), confidence=0.22947368421052633, lift=1.3426537482551935)]),
#  RelationRecord(items=frozenset({'green tea', 'french fries'}), support=0.028529529396080524, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea'}), items_add=frozenset({'french fries'}), confidence=0.21594349142280528, lift=1.263488400282732)]),
#  RelationRecord(items=frozenset({'ham', 'french fries'}), support=0.005599253432875617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'french fries'}), confidence=0.21105527638190955, lift=1.2348873854451667)]),
#  RelationRecord(items=frozenset({'hot dogs', 'french fries'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hot dogs'}), items_add=frozenset({'french fries'}), confidence=0.2263374485596708, lift=1.324303589427528)]),
#  RelationRecord(items=frozenset({'light mayo', 'french fries'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light mayo'}), items_add=frozenset({'french fries'}), confidence=0.2696078431372549, lift=1.577479275641614)]),
#  RelationRecord(items=frozenset({'muffins', 'french fries'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'muffins'}), items_add=frozenset({'french fries'}), confidence=0.22099447513812154, lift=1.2930417769196956)]),
# ...
#  RelationRecord(items=frozenset({'green tea', 'eggs', 'frozen vegetables'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.2314814814814815, lift=1.2880879767007365)]),
#  RelationRecord(items=frozenset({'ground beef', 'eggs', 'frozen vegetables'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'ground beef'}), confidence=0.20245398773006135, lift=2.0605255928944235), OrderedStatistic(items_base=frozenset({'ground beef', 'eggs'}), items_add=frozenset({'frozen vegetables'}), confidence=0.22000000000000003, lift=2.3080000000000003), OrderedStatistic(items_base=frozenset({'ground beef', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.25984251968503935, lift=1.44590410990911)]),
#  RelationRecord(items=frozenset({'low fat yogurt', 'eggs', 'frozen vegetables'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'low fat yogurt', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.31578947368421056, lift=1.757223176635952)]),
#  RelationRecord(items=frozenset({'milk', 'eggs', 'frozen vegetables'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.3374233128834356, lift=2.6039220884142495), OrderedStatistic(items_base=frozenset({'milk', 'eggs'}), items_add=frozenset({'frozen vegetables'}), confidence=0.2380952380952381, lift=2.497835497835498), OrderedStatistic(items_base=frozenset({'milk', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.3107344632768361, lift=1.7290943687237001)]),
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables', 'mineral water'}), support=0.009065457938941474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'mineral water'}), confidence=0.41717791411042937, lift=1.750140678826807), OrderedStatistic(items_base=frozenset({'frozen vegetables', 'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.25373134328358204, lift=1.4118982240134637)]),
#  RelationRecord(items=frozenset({'nan', 'eggs', 'frozen vegetables'}), support=0.021730435941874418, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'nan', 'eggs'}), confidence=0.22797202797202798, lift=1.2685594820609658), OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.22797202797202798, lift=1.2685594820609658)]),
#  RelationRecord(items=frozenset({'pancakes', 'eggs', 'frozen vegetables'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.22772277227722773, lift=1.2671724887622293)]),
#  RelationRecord(items=frozenset({'shrimp', 'eggs', 'frozen vegetables'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shrimp', 'eggs'}), items_add=frozenset({'frozen vegetables'}), confidence=0.2641509433962264, lift=2.7711835334476844), OrderedStatistic(items_base=frozenset({'shrimp', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.22399999999999998, lift=1.2464569732937685)]),
#  RelationRecord(items=frozenset({'spaghetti', 'eggs', 'frozen vegetables'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'spaghetti'}), confidence=0.26380368098159507, lift=1.5151542197878596), OrderedStatistic(items_base=frozenset({'spaghetti', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.20574162679425836, lift=1.144857524171908)]),
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables', 'tomatoes'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'tomatoes'}), items_add=frozenset({'frozen vegetables'}), confidence=0.25, lift=2.6227272727272726)]),
#  RelationRecord(items=frozenset({'eggs', 'grated cheese', 'mineral water'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'grated cheese'}), items_add=frozenset({'mineral water'}), confidence=0.4852941176470589, lift=2.0359011054086067), OrderedStatistic(items_base=frozenset({'grated cheese', 'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.2519083969465649, lift=1.4017543660950915)]),
#  RelationRecord(items=frozenset({'nan', 'eggs', 'grated cheese'}), support=0.009065457938941474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'grated cheese'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'eggs', 'grated cheese'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'grated cheese'}), items_add=frozenset({'spaghetti'}), confidence=0.47058823529411764, lift=2.7028195658048824), OrderedStatistic(items_base=frozenset({'spaghetti', 'grated cheese'}), items_add=frozenset({'eggs'}), confidence=0.25806451612903225, lift=1.4360103378960467)]),
#  RelationRecord(items=frozenset({'green tea', 'eggs', 'milk'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea', 'milk'}), items_add=frozenset({'eggs'}), confidence=0.2196969696969697, lift=1.2225125887959716)]),
#  RelationRecord(items=frozenset({'green tea', 'eggs', 'mineral water'}), support=0.006932409012131715, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea', 'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.2722513089005235, lift=1.1421460112208204), OrderedStatistic(items_base=frozenset({'green tea', 'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.22317596566523604, lift=1.241871601227697)]),
#  RelationRecord(items=frozenset({'nan', 'green tea', 'eggs'}), support=0.025463271563791495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea', 'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'pancakes', 'green tea', 'eggs'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes', 'green tea'}), items_add=frozenset({'eggs'}), confidence=0.21951219512195122, lift=1.2214844032713323)]),
#  RelationRecord(items=frozenset({'spaghetti', 'green tea', 'eggs'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea', 'eggs'}), items_add=frozenset({'spaghetti'}), confidence=0.225130890052356, lift=1.293037370813723), OrderedStatistic(items_base=frozenset({'spaghetti', 'green tea'}), items_add=frozenset({'eggs'}), confidence=0.21608040201005024, lift=1.2023880530247677)]),
#  RelationRecord(items=frozenset({'green tea', 'eggs', 'turkey'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea', 'turkey'}), items_add=frozenset({'eggs'}), confidence=0.32584269662921345, lift=1.8131647384389689)]),
#  RelationRecord(items=frozenset({'herb & pepper', 'ground beef', 'eggs'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef', 'eggs'}), items_add=frozenset({'herb & pepper'}), confidence=0.2066666666666667, lift=4.178454627133872), OrderedStatistic(items_base=frozenset({'herb & pepper', 'eggs'}), items_add=frozenset({'ground beef'}), confidence=0.3297872340425532, lift=3.3564912381997174), OrderedStatistic(items_base=frozenset({'ground beef', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.2583333333333333, lift=1.4375061819980215)]),
#  RelationRecord(items=frozenset({'ground beef', 'eggs', 'milk'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef', 'eggs'}), items_add=frozenset({'milk'}), confidence=0.29333333333333333, lift=2.2636762688614542), OrderedStatistic(items_base=frozenset({'ground beef', 'milk'}), items_add=frozenset({'eggs'}), confidence=0.26666666666666666, lift=1.4838773491592483)]),
#  RelationRecord(items=frozenset({'ground beef', 'eggs', 'mineral water'}), support=0.010131982402346354, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef', 'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.5066666666666667, lift=2.125563012677107), OrderedStatistic(items_base=frozenset({'ground beef', 'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.247557003257329, lift=1.3775408615973477)]),
#  RelationRecord(items=frozenset({'nan', 'ground beef', 'eggs'}), support=0.019997333688841486, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'nan', 'eggs'}), confidence=0.20352781546811397, lift=1.132538682363741), OrderedStatistic(items_base=frozenset({'ground beef', 'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'ground beef'}), items_add=frozenset({'eggs'}), confidence=0.20352781546811397, lift=1.132538682363741)]),
#  RelationRecord(items=frozenset({'spaghetti', 'ground beef', 'eggs'}), support=0.008932142381015865, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef', 'eggs'}), items_add=frozenset({'spaghetti'}), confidence=0.4466666666666667, lift=2.565426237876468), OrderedStatistic(items_base=frozenset({'spaghetti', 'eggs'}), items_add=frozenset({'ground beef'}), confidence=0.2445255474452555, lift=2.4887193098871934), OrderedStatistic(items_base=frozenset({'spaghetti', 'ground beef'}), items_add=frozenset({'eggs'}), confidence=0.22789115646258504, lift=1.2681094693070107)]),
#  RelationRecord(items=frozenset({'ham', 'nan', 'eggs'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'nan', 'eggs'}), confidence=0.23618090452261306, lift=1.3142381044689322), OrderedStatistic(items_base=frozenset({'ham', 'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'ham', 'nan'}), items_add=frozenset({'eggs'}), confidence=0.23618090452261306, lift=1.3142381044689322)]),
#  RelationRecord(items=frozenset({'herb & pepper', 'milk', 'eggs'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper', 'eggs'}), items_add=frozenset({'milk'}), confidence=0.26595744680851063, lift=2.0524144120479817), OrderedStatistic(items_base=frozenset({'milk', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.36231884057971014, lift=2.016137702662022)]),
#  RelationRecord(items=frozenset({'herb & pepper', 'eggs', 'mineral water'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper', 'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.425531914893617, lift=1.7851873006806607), OrderedStatistic(items_base=frozenset({'herb & pepper', 'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.3125, lift=1.738918768545994)]),
#  RelationRecord(items=frozenset({'nan', 'herb & pepper', 'eggs'}), support=0.012531662445007332, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'nan', 'eggs'}), confidence=0.25336927223719674, lift=1.4098834651715229), OrderedStatistic(items_base=frozenset({'herb & pepper', 'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.25336927223719674, lift=1.4098834651715229)]),
#  RelationRecord(items=frozenset({'spaghetti', 'herb & pepper', 'eggs'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper', 'eggs'}), items_add=frozenset({'spaghetti'}), confidence=0.3829787234042553, lift=2.1996350721709947), OrderedStatistic(items_base=frozenset({'spaghetti', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.29508196721311475, lift=1.6419954273483484)]),
#  RelationRecord(items=frozenset({'nan', 'honey', 'eggs'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'honey', 'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'nan', 'eggs', 'hot dogs'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'hot dogs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'light cream', 'nan', 'eggs'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'nan', 'eggs'}), confidence=0.2136752136752137, lift=1.1890042861852952), OrderedStatistic(items_base=frozenset({'light cream', 'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'light cream', 'nan'}), items_add=frozenset({'eggs'}), confidence=0.2136752136752137, lift=1.1890042861852952)]),
#  RelationRecord(items=frozenset({'nan', 'eggs', 'light mayo'}), support=0.005465937874950006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light mayo'}), items_add=frozenset({'nan', 'eggs'}), confidence=0.20098039215686272, lift=1.1183634433001686), OrderedStatistic(items_base=frozenset({'eggs', 'light mayo'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'light mayo'}), items_add=frozenset({'eggs'}), confidence=0.20098039215686272, lift=1.1183634433001686)]),
#  RelationRecord(items=frozenset({'low fat yogurt', 'milk', 'eggs'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'low fat yogurt', 'eggs'}), items_add=frozenset({'milk'}), confidence=0.2222222222222222, lift=1.7149062642889803), OrderedStatistic(items_base=frozenset({'low fat yogurt', 'milk'}), items_add=frozenset({'eggs'}), confidence=0.2828282828282828, lift=1.5738093097143542)]),
#  RelationRecord(items=frozenset({'low fat yogurt', 'eggs', 'mineral water'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'low fat yogurt', 'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.36507936507936506, lift=1.5315773587585668), OrderedStatistic(items_base=frozenset({'low fat yogurt', 'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.2555555555555556, lift=1.4220491262776132)]),
#  RelationRecord(items=frozenset({'low fat yogurt', 'nan', 'eggs'}), support=0.01679776029862685, ordered_statistics=[OrderedStatistic(items_base=frozenset({'low fat yogurt'}), items_add=frozenset({'nan', 'eggs'}), confidence=0.21951219512195125, lift=1.2214844032713326), OrderedStatistic(items_base=frozenset({'low fat yogurt', 'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'low fat yogurt', 'nan'}), items_add=frozenset({'eggs'}), confidence=0.2198952879581152, lift=1.2236161387046158)]),
#  RelationRecord(items=frozenset({'spaghetti', 'low fat yogurt', 'eggs'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'low fat yogurt', 'eggs'}), items_add=frozenset({'spaghetti'}), confidence=0.2222222222222222, lift=1.2763314616300834), OrderedStatistic(items_base=frozenset({'spaghetti', 'low fat yogurt'}), items_add=frozenset({'eggs'}), confidence=0.24561403508771928, lift=1.366729137383518)]),
#  ...]

# %%
result
# Out:
# [['mineral water'],
#  ['nan'],
#  ['burgers', 'almonds'],
#  ['almonds', 'chocolate'],
#  ['almonds', 'eggs'],
#  ['almonds', 'french fries'],
#  ['almonds', 'green tea'],
#  ['almonds', 'milk'],
#  ['almonds', 'mineral water'],
#  ['nan', 'almonds'],
#  ['spaghetti', 'almonds'],
#  ['nan', 'antioxydant juice'],
#  ['nan', 'asparagus'],
#  ['avocado', 'chocolate'],
#  ['avocado', 'french fries'],
#  ['milk', 'avocado'],
#  ['avocado', 'mineral water'],
#  ['nan', 'avocado'],
#  ['spaghetti', 'avocado'],
#  ['nan', 'babies food'],
#  ['bacon', 'mineral water'],
#  ['bacon', 'nan'],
#  ['bacon', 'spaghetti'],
#  ['eggs', 'barbecue sauce'],
#  ['barbecue sauce', 'mineral water'],
#  ['nan', 'barbecue sauce'],
#  ['black tea', 'eggs'],
#  ['black tea', 'milk'],
#  ['black tea', 'mineral water'],
#  ['nan', 'black tea'],
#  ['spaghetti', 'black tea'],
#  ['blueberries', 'mineral water'],
#  ['nan', 'blueberries'],
#  ['spaghetti', 'blueberries'],
#  ['body spray', 'french fries'],
#  ['body spray', 'mineral water'],
#  ['nan', 'body spray'],
#  ['eggs', 'brownies'],
#  ['brownies', 'french fries'],
#  ['mineral water', 'brownies'],
#  ['nan', 'brownies'],
#  ['spaghetti', 'brownies'],
#  ['bug spray', 'nan'],
#  ['nan', 'burger sauce'],
#  ['burgers', 'eggs'],
#  ['burgers', 'french fries'],
#  ['burgers', 'green tea'],
#  ['burgers', 'ham'],
#  ['burgers', 'milk'],
#  ['burgers', 'mineral water'],
#  ['burgers', 'nan'],
#  ['spaghetti', 'burgers'],
#  ['butter', 'chocolate'],
#  ['butter', 'eggs'],
#  ['butter', 'french fries'],
#  ['butter', 'green tea'],
#  ['butter', 'milk'],
#  ['nan', 'butter'],
#  ['spaghetti', 'butter'],
#  ['cake', 'eggs'],
#  ['cake', 'french fries'],
#  ['cake', 'mineral water'],
#  ['nan', 'cake'],
#  ['spaghetti', 'cake'],
#  ['nan', 'candy bars'],
#  ['chocolate', 'carrots'],
#  ['green tea', 'carrots'],
#  ['mineral water', 'carrots'],
#  ['nan', 'carrots'],
#  ['spaghetti', 'carrots'],
#  ['nan', 'cauliflower'],
#  ['cereals', 'chocolate'],
#  ['cereals', 'green tea'],
#  ['cereals', 'milk'],
#  ['cereals', 'mineral water'],
#  ['cereals', 'nan'],
#  ['cereals', 'spaghetti'],
#  ['champagne', 'chocolate'],
#  ['champagne', 'nan'],
#  ['chicken', 'chocolate'],
#  ['eggs', 'chicken'],
#  ['light cream', 'chicken'],
#  ['milk', 'chicken'],
#  ['chicken', 'mineral water'],
#  ['nan', 'chicken'],
#  ['spaghetti', 'chicken'],
#  ['nan', 'chili'],
#  ['cooking oil', 'chocolate'],
#  ['eggs', 'chocolate'],
#  ['escalope', 'chocolate'],
#  ['chocolate', 'french fries'],
#  ['chocolate', 'french wine'],
#  ['fresh bread', 'chocolate'],
#  ['fresh tuna', 'chocolate'],
#  ['fromage blanc', 'chocolate'],
#  ['frozen smoothie', 'chocolate'],
#  ['frozen vegetables', 'chocolate'],
#  ['grated cheese', 'chocolate'],
#  ['ground beef', 'chocolate'],
#  ['ham', 'chocolate'],
#  ['light cream', 'chocolate'],
#  ['milk', 'chocolate'],
#  ['chocolate', 'mineral water'],
#  ['mushroom cream sauce', 'chocolate'],
#  ['nan', 'chocolate'],
#  ['chocolate', 'oil'],
#  ['olive oil', 'chocolate'],
#  ['pancakes', 'chocolate'],
#  ['parmesan cheese', 'chocolate'],
#  ['chocolate', 'pepper'],
#  ['rice', 'chocolate'],
#  ['salmon', 'chocolate'],
#  ['shrimp', 'chocolate'],
#  ['soup', 'chocolate'],
#  ['spaghetti', 'chocolate'],
#  ['tomato sauce', 'chocolate'],
#  ['chocolate', 'tomatoes'],
#  ['chocolate', 'white wine'],
#  ['whole wheat pasta', 'chocolate'],
#  ['whole wheat rice', 'chocolate'],
#  ['chocolate bread', 'nan'],
#  ['chutney', 'nan'],
#  ['cider', 'eggs'],
#  ['cider', 'milk'],
#  ['nan', 'cider'],
#  ['clothes accessories', 'nan'],
#  ['nan', 'cookies'],
#  ['cooking oil', 'eggs'],
#  ['cooking oil', 'milk'],
#  ['cooking oil', 'mineral water'],
#  ['cooking oil', 'nan'],
#  ['spaghetti', 'cooking oil'],
#  ['nan', 'corn'],
#  ['green tea', 'cottage cheese'],
#  ['cottage cheese', 'mineral water'],
#  ['nan', 'cottage cheese'],
#  ['spaghetti', 'cottage cheese'],
#  ['dessert wine', 'nan'],
#  ['eggs', 'eggplant'],
#  ['eggplant', 'mineral water'],
#  ['nan', 'eggplant'],
#  ['spaghetti', 'eggplant'],
#  ['eggs', 'french fries'],
#  ['eggs', 'french wine'],
#  ['fresh bread', 'eggs'],
#  ['eggs', 'fresh tuna'],
#  ['eggs', 'fromage blanc'],
#  ['eggs', 'frozen vegetables'],
#  ['ground beef', 'eggs'],
#  ['ham', 'eggs'],
#  ['herb & pepper', 'eggs'],
#  ['light cream', 'eggs'],
#  ['eggs', 'light mayo'],
#  ['low fat yogurt', 'eggs'],
#  ['meatballs', 'eggs'],
#  ['milk', 'eggs'],
#  ['eggs', 'mineral water'],
#  ['nan', 'eggs'],
#  ['pancakes', 'eggs'],
#  ['parmesan cheese', 'eggs'],
#  ['red wine', 'eggs'],
#  ['spaghetti', 'eggs'],
#  ['eggs', 'turkey'],
#  ['milk', 'energy bar'],
#  ['mineral water', 'energy bar'],
#  ['nan', 'energy bar'],
#  ['energy drink', 'french fries'],
#  ['mineral water', 'energy drink'],
#  ['nan', 'energy drink'],
#  ['escalope', 'french fries'],
#  ['escalope', 'mineral water'],
#  ['escalope', 'mushroom cream sauce'],
#  ['escalope', 'nan'],
#  ['pasta', 'escalope'],
#  ['mineral water', 'extra dark chocolate'],
#  ['nan', 'extra dark chocolate'],
#  ['spaghetti', 'extra dark chocolate'],
#  ['flax seed', 'green tea'],
#  ['nan', 'flax seed'],
#  ['fromage blanc', 'french fries'],
#  ['frozen smoothie', 'french fries'],
#  ['green tea', 'french fries'],
#  ['ham', 'french fries'],
#  ['hot dogs', 'french fries'],
#  ['light mayo', 'french fries'],
#  ['muffins', 'french fries'],
#  ['mushroom cream sauce', 'french fries'],
#  ['nan', 'french fries'],
#  ['pancakes', 'french fries'],
#  ['rice', 'french fries'],
#  ['strawberries', 'french fries'],
#  ['tomato juice', 'french fries'],
#  ['vegetables mix', 'french fries'],
#  ['milk', 'french wine'],
#  ['mineral water', 'french wine'],
#  ['nan', 'french wine'],
#  ['spaghetti', 'french wine'],
#  ['fresh bread', 'milk'],
#  ['fresh bread', 'mineral water'],
#  ['nan', 'fresh bread'],
#  ['spaghetti', 'fresh bread'],
#  ['milk', 'fresh tuna'],
#  ['fresh tuna', 'mineral water'],
#  ['nan', 'fresh tuna'],
#  ['pancakes', 'fresh tuna'],
#  ['spaghetti', 'fresh tuna'],
#  ['honey', 'fromage blanc'],
#  ['fromage blanc', 'mineral water'],
#  ['nan', 'fromage blanc'],
#  ['spaghetti', 'fromage blanc'],
#  ['milk', 'frozen smoothie'],
#  ['frozen smoothie', 'mineral water'],
#  ['nan', 'frozen smoothie'],
#  ['spaghetti', 'frozen smoothie'],
#  ['milk', 'frozen vegetables'],
#  ['frozen vegetables', 'mineral water'],
#  ['nan', 'frozen vegetables'],
#  ['parmesan cheese', 'frozen vegetables'],
#  ['shrimp', 'frozen vegetables'],
#  ['spaghetti', 'frozen vegetables'],
#  ['frozen vegetables', 'tomatoes'],
#  ['nan', 'gluten free bar'],
#  ['ground beef', 'grated cheese'],
#  ['grated cheese', 'mineral water'],
#  ['nan', 'grated cheese'],
#  ['spaghetti', 'grated cheese'],
#  ['nan', 'green beans'],
#  ['spaghetti', 'green beans'],
#  ['green grapes', 'mineral water'],
#  ['nan', 'green grapes'],
#  ['green tea', 'gums'],
#  ['green tea', 'hot dogs'],
#  ['green tea', 'mineral water'],
#  ['nan', 'green tea'],
#  ['spaghetti', 'green tea'],
#  ['green tea', 'tomato juice'],
#  ['ground beef', 'herb & pepper'],
#  ['light cream', 'ground beef'],
#  ['ground beef', 'milk'],
#  ['ground beef', 'mineral water'],
#  ['nan', 'ground beef'],
#  ['olive oil', 'ground beef'],
#  ['ground beef', 'pepper'],
#  ['ground beef', 'rice'],
#  ['ground beef', 'salmon'],
#  ['spaghetti', 'ground beef'],
#  ['ground beef', 'tomato sauce'],
#  ['mineral water', 'gums'],
#  ['nan', 'gums'],
#  ['spaghetti', 'gums'],
#  ['ham', 'mineral water'],
#  ['ham', 'nan'],
#  ['spaghetti', 'ham'],
#  ['nan', 'hand protein bar'],
#  ['herb & pepper', 'mineral water'],
#  ['nan', 'herb & pepper'],
#  ['spaghetti', 'herb & pepper'],
#  ['honey', 'mineral water'],
#  ['nan', 'honey'],
#  ['spaghetti', 'honey'],
#  ['hot dogs', 'mineral water'],
#  ['nan', 'hot dogs'],
#  ['spaghetti', 'hot dogs'],
#  ['ketchup', 'nan'],
#  ['light cream', 'milk'],
#  ['light cream', 'mineral water'],
#  ['light cream', 'nan'],
#  ['olive oil', 'light cream'],
#  ['pancakes', 'light cream'],
#  ['spaghetti', 'light cream'],
#  ['light mayo', 'mineral water'],
#  ['nan', 'light mayo'],
#  ['pancakes', 'light mayo'],
#  ['low fat yogurt', 'mineral water'],
#  ['low fat yogurt', 'nan'],
#  ['magazines', 'mineral water'],
#  ['nan', 'magazines'],
#  ['nan', 'mashed potato'],
#  ['nan', 'mayonnaise'],
#  ['meatballs', 'milk'],
#  ['meatballs', 'mineral water'],
#  ['meatballs', 'nan'],
#  ['meatballs', 'spaghetti'],
#  ['nan', 'melons'],
#  ['milk', 'mineral water'],
#  ['nan', 'milk'],
#  ['olive oil', 'milk'],
#  ['milk', 'salmon'],
#  ['milk', 'shrimp'],
#  ['milk', 'soup'],
#  ['spaghetti', 'milk'],
#  ['milk', 'tomatoes'],
#  ['milk', 'white wine'],
#  ['milk', 'whole wheat pasta'],
#  ['whole wheat rice', 'milk'],
#  ['mint', 'mineral water'],
#  ['nan', 'mineral water'],
#  ['nonfat milk', 'mineral water'],
#  ['mineral water', 'oil'],
#  ['olive oil', 'mineral water'],
#  ['pancakes', 'mineral water'],
#  ['parmesan cheese', 'mineral water'],
#  ['pepper', 'mineral water'],
#  ['protein bar', 'mineral water'],
#  ['red wine', 'mineral water'],
#  ['rice', 'mineral water'],
#  ['salmon', 'mineral water'],
#  ['shrimp', 'mineral water'],
#  ['soup', 'mineral water'],
#  ['spaghetti', 'mineral water'],
#  ['strawberries', 'mineral water'],
#  ['strong cheese', 'mineral water'],
#  ['tomato juice', 'mineral water'],
#  ['tomato sauce', 'mineral water'],
#  ['mineral water', 'tomatoes'],
#  ['mineral water', 'turkey'],
#  ['vegetables mix', 'mineral water'],
#  ['mineral water', 'white wine'],
#  ['whole weat flour', 'mineral water'],
#  ['whole wheat pasta', 'mineral water'],
#  ['whole wheat rice', 'mineral water'],
#  ['yams', 'mineral water'],
#  ['yogurt cake', 'mineral water'],
#  ['zucchini', 'mineral water'],
#  ['nan', 'mint'],
#  ['spaghetti', 'mint'],
#  ['mint green tea', 'nan'],
#  ['muffins', 'nan'],
#  ['mushroom cream sauce', 'nan'],
#  ['spaghetti', 'mushroom cream sauce'],
#  ['nonfat milk', 'nan'],
#  ['oatmeal', 'nan'],
#  ['nan', 'oil'],
#  ['olive oil', 'nan'],
#  ['pancakes', 'nan'],
#  ['parmesan cheese', 'nan'],
#  ['pasta', 'nan'],
#  ['nan', 'pepper'],
#  ['nan', 'pet food'],
#  ['pickles', 'nan'],
#  ['nan', 'protein bar'],
#  ['red wine', 'nan'],
#  ['nan', 'rice'],
#  ['nan', 'salad'],
#  ['nan', 'salmon'],
#  ['nan', 'salt'],
#  ['nan', 'sandwich'],
#  ['nan', 'shallot'],
#  ['nan', 'shampoo'],
#  ['nan', 'shrimp'],
#  ['soda', 'nan'],
#  ['nan', 'soup'],
#  ['spaghetti', 'nan'],
#  ['nan', 'sparkling water'],
#  ['nan', 'spinach'],
#  ['nan', 'strawberries'],
#  ['nan', 'strong cheese'],
#  ['tea', 'nan'],
#  ['nan', 'tomato juice'],
#  ['nan', 'tomato sauce'],
#  ['nan', 'tomatoes'],
#  ['toothpaste', 'nan'],
#  ['nan', 'turkey'],
#  ['nan', 'vegetables mix'],
#  ['nan', 'white wine'],
#  ['nan', 'whole weat flour'],
#  ['nan', 'whole wheat pasta'],
#  ['nan', 'whole wheat rice'],
#  ['nan', 'yams'],
#  ['nan', 'yogurt cake'],
#  ['zucchini', 'nan'],
#  ['spaghetti', 'nonfat milk'],
#  ['spaghetti', 'oil'],
#  ['olive oil', 'spaghetti'],
#  ['olive oil', 'whole wheat pasta'],
#  ['pancakes', 'spaghetti'],
#  ['parmesan cheese', 'spaghetti'],
#  ['pasta', 'shrimp'],
#  ['spaghetti', 'pepper'],
#  ['spaghetti', 'protein bar'],
#  ['red wine', 'spaghetti'],
#  ['spaghetti', 'rice'],
#  ['spaghetti', 'salmon'],
#  ['spaghetti', 'shrimp'],
#  ['spaghetti', 'soup'],
#  ['spaghetti', 'strong cheese'],
#  ['spaghetti', 'tomato juice'],
#  ['spaghetti', 'tomato sauce'],
#  ['spaghetti', 'tomatoes'],
#  ['spaghetti', 'turkey'],
#  ['spaghetti', 'vegetables mix'],
#  ['spaghetti', 'white wine'],
#  ['spaghetti', 'whole wheat pasta'],
#  ['spaghetti', 'whole wheat rice'],
#  ['spaghetti', 'zucchini'],
#  ['burgers', 'almonds', 'nan'],
#  ['cake', 'almonds', 'nan'],
#  ['nan', 'almonds', 'chocolate'],
#  ['nan', 'almonds', 'eggs'],
#  ['nan', 'almonds', 'french fries'],
#  ['nan', 'almonds', 'frozen vegetables'],
#  ['nan', 'almonds', 'green tea'],
#  ['nan', 'almonds', 'ground beef'],
#  ['nan', 'almonds', 'milk'],
#  ['nan', 'almonds', 'mineral water'],
#  ['pancakes', 'nan', 'almonds'],
#  ['spaghetti', 'nan', 'almonds'],
#  ['burgers', 'nan', 'avocado'],
#  ['nan', 'cake', 'avocado'],
#  ['avocado', 'chocolate', 'mineral water'],
#  ['nan', 'avocado', 'chocolate'],
#  ['nan', 'eggs', 'avocado'],
#  ['nan', 'avocado', 'french fries'],
#  ['nan', 'avocado', 'frozen smoothie'],
#  ['nan', 'avocado', 'frozen vegetables'],
#  ['nan', 'green tea', 'avocado'],
#  ['nan', 'ground beef', 'avocado'],
#  ['nan', 'honey', 'avocado'],
#  ['milk', 'avocado', 'mineral water'],
#  ['nan', 'milk', 'avocado'],
#  ['spaghetti', 'milk', 'avocado'],
#  ['nan', 'avocado', 'mineral water'],
#  ['olive oil', 'nan', 'avocado'],
#  ['pancakes', 'nan', 'avocado'],
#  ['soup', 'nan', 'avocado'],
#  ['spaghetti', 'nan', 'avocado'],
#  ['nan', 'avocado', 'tomatoes'],
#  ['nan', 'avocado', 'turkey'],
#  ['nan', 'whole wheat rice', 'avocado'],
#  ['bacon', 'nan', 'mineral water'],
#  ['bacon', 'nan', 'spaghetti'],
#  ['nan', 'eggs', 'barbecue sauce'],
#  ['nan', 'barbecue sauce', 'mineral water'],
#  ['nan', 'black tea', 'eggs'],
#  ['nan', 'black tea', 'milk'],
#  ['nan', 'black tea', 'mineral water'],
#  ['spaghetti', 'nan', 'black tea'],
#  ['nan', 'blueberries', 'mineral water'],
#  ['spaghetti', 'nan', 'blueberries'],
#  ['nan', 'body spray', 'french fries'],
#  ['nan', 'body spray', 'mineral water'],
#  ['burgers', 'nan', 'brownies'],
#  ['nan', 'cake', 'brownies'],
#  ['nan', 'chocolate', 'brownies'],
#  ['nan', 'cottage cheese', 'brownies'],
#  ['eggs', 'mineral water', 'brownies'],
#  ['nan', 'eggs', 'brownies'],
#  ['nan', 'brownies', 'french fries'],
#  ['nan', 'frozen vegetables', 'brownies'],
#  ['nan', 'green tea', 'brownies'],
#  ['nan', 'ground beef', 'brownies'],
#  ['low fat yogurt', 'nan', 'brownies'],
#  ['nan', 'milk', 'brownies'],
#  ['nan', 'mineral water', 'brownies'],
#  ['olive oil', 'nan', 'brownies'],
#  ['pancakes', 'nan', 'brownies'],
#  ['nan', 'shrimp', 'brownies'],
#  ['spaghetti', 'nan', 'brownies'],
#  ['burgers', 'butter', 'nan'],
#  ['burgers', 'cake', 'chocolate'],
#  ['burgers', 'cake', 'eggs'],
#  ['burgers', 'cake', 'milk'],
#  ['burgers', 'cake', 'mineral water'],
#  ['burgers', 'cake', 'nan'],
#  ['cereals', 'burgers', 'nan'],
#  ['champagne', 'burgers', 'nan'],
#  ['burgers', 'nan', 'chicken'],
#  ['burgers', 'eggs', 'chocolate'],
#  ['burgers', 'chocolate', 'french fries'],
#  ['burgers', 'frozen vegetables', 'chocolate'],
#  ['burgers', 'green tea', 'chocolate'],
#  ['burgers', 'ground beef', 'chocolate'],
#  ['burgers', 'milk', 'chocolate'],
#  ['burgers', 'chocolate', 'mineral water'],
#  ['burgers', 'nan', 'chocolate'],
#  ['pancakes', 'burgers', 'chocolate'],
#  ['burgers', 'shrimp', 'chocolate'],
#  ['spaghetti', 'burgers', 'chocolate'],
#  ['burgers', 'chocolate', 'turkey'],
#  ['burgers', 'nan', 'cookies'],
#  ['burgers', 'cooking oil', 'nan'],
#  ['burgers', 'nan', 'cottage cheese'],
#  ['burgers', 'eggs', 'french fries'],
#  ['burgers', 'green tea', 'eggs'],
#  ['burgers', 'ground beef', 'eggs'],
#  ['burgers', 'milk', 'eggs'],
#  ['burgers', 'eggs', 'mineral water'],
#  ['burgers', 'nan', 'eggs'],
#  ['pancakes', 'burgers', 'eggs'],
#  ['spaghetti', 'burgers', 'eggs'],
#  ['burgers', 'eggs', 'turkey'],
#  ['burgers', 'nan', 'escalope'],
#  ['burgers', 'green tea', 'french fries'],
#  ['burgers', 'milk', 'french fries'],
#  ['burgers', 'mineral water', 'french fries'],
#  ['burgers', 'nan', 'french fries'],
#  ['pancakes', 'burgers', 'french fries'],
#  ['spaghetti', 'burgers', 'french fries'],
#  ['burgers', 'nan', 'french wine'],
#  ['burgers', 'nan', 'fresh bread'],
#  ['burgers', 'nan', 'fresh tuna'],
#  ['burgers', 'frozen smoothie', 'mineral water'],
#  ['burgers', 'nan', 'frozen smoothie'],
#  ['burgers', 'frozen vegetables', 'mineral water'],
#  ['burgers', 'nan', 'frozen vegetables'],
#  ['spaghetti', 'burgers', 'frozen vegetables'],
#  ['burgers', 'nan', 'grated cheese'],
#  ['burgers', 'green tea', 'milk'],
#  ['burgers', 'nan', 'green tea'],
#  ['spaghetti', 'burgers', 'green tea'],
#  ['burgers', 'ground beef', 'milk'],
#  ['burgers', 'ground beef', 'mineral water'],
#  ['burgers', 'nan', 'ground beef'],
#  ['spaghetti', 'burgers', 'ground beef'],
#  ['burgers', 'nan', 'ham'],
#  ['burgers', 'nan', 'herb & pepper'],
#  ['burgers', 'nan', 'honey'],
#  ['burgers', 'nan', 'hot dogs'],
#  ['burgers', 'nan', 'light mayo'],
#  ['burgers', 'low fat yogurt', 'nan'],
#  ['burgers', 'milk', 'mineral water'],
#  ['burgers', 'nan', 'milk'],
#  ['spaghetti', 'burgers', 'milk'],
#  ['burgers', 'milk', 'turkey'],
#  ['burgers', 'whole wheat rice', 'milk'],
#  ['burgers', 'nan', 'mineral water'],
#  ['olive oil', 'burgers', 'mineral water'],
#  ['pancakes', 'burgers', 'mineral water'],
#  ['burgers', 'shrimp', 'mineral water'],
#  ['spaghetti', 'burgers', 'mineral water'],
#  ['burgers', 'mineral water', 'tomatoes'],
#  ['burgers', 'mineral water', 'turkey'],
#  ['burgers', 'whole wheat rice', 'mineral water'],
#  ['olive oil', 'burgers', 'nan'],
#  ['pancakes', 'burgers', 'nan'],
#  ['red wine', 'burgers', 'nan'],
#  ['burgers', 'nan', 'salmon'],
#  ['burgers', 'nan', 'shrimp'],
#  ['burgers', 'nan', 'soup'],
#  ['spaghetti', 'burgers', 'nan'],
#  ['burgers', 'nan', 'tomato juice'],
#  ['burgers', 'nan', 'tomatoes'],
#  ['burgers', 'nan', 'turkey'],
#  ['burgers', 'nan', 'whole wheat pasta'],
#  ['burgers', 'nan', 'whole wheat rice'],
#  ['pancakes', 'burgers', 'spaghetti'],
#  ['spaghetti', 'burgers', 'turkey'],
#  ['spaghetti', 'burgers', 'whole wheat rice'],
#  ['nan', 'butter', 'chicken'],
#  ['nan', 'butter', 'chocolate'],
#  ['cooking oil', 'butter', 'nan'],
#  ['nan', 'butter', 'eggs'],
#  ['nan', 'butter', 'french fries'],
#  ['nan', 'butter', 'frozen vegetables'],
#  ['nan', 'butter', 'grated cheese'],
#  ['nan', 'butter', 'green tea'],
#  ['nan', 'butter', 'ground beef'],
#  ['low fat yogurt', 'butter', 'nan'],
#  ['nan', 'butter', 'milk'],
#  ['nan', 'butter', 'mineral water'],
#  ['pancakes', 'nan', 'butter'],
#  ['nan', 'butter', 'shrimp'],
#  ['spaghetti', 'nan', 'butter'],
#  ['nan', 'butter', 'tomatoes'],
#  ['nan', 'butter', 'whole wheat rice'],
#  ['cereals', 'nan', 'cake'],
#  ['cake', 'chicken', 'mineral water'],
#  ['nan', 'cake', 'chicken'],
#  ['cake', 'eggs', 'chocolate'],
#  ['cake', 'chocolate', 'french fries'],
#  ['cake', 'milk', 'chocolate'],
#  ['cake', 'chocolate', 'mineral water'],
#  ['nan', 'cake', 'chocolate'],
#  ['spaghetti', 'cake', 'chocolate'],
#  ['nan', 'cake', 'cookies'],
#  ['cooking oil', 'cake', 'nan'],
#  ['nan', 'cake', 'cottage cheese'],
#  ['cake', 'eggs', 'french fries'],
#  ['cake', 'green tea', 'eggs'],
#  ['cake', 'milk', 'eggs'],
#  ['cake', 'eggs', 'mineral water'],
#  ['nan', 'cake', 'eggs'],
#  ['pancakes', 'cake', 'eggs'],
#  ['spaghetti', 'cake', 'eggs'],
#  ['cake', 'eggs', 'turkey'],
#  ['nan', 'cake', 'energy bar'],
#  ['nan', 'cake', 'energy drink'],
#  ['escalope', 'cake', 'nan'],
#  ['cake', 'green tea', 'french fries'],
#  ['cake', 'milk', 'french fries'],
#  ['cake', 'mineral water', 'french fries'],
#  ['nan', 'cake', 'french fries'],
#  ['spaghetti', 'cake', 'french fries'],
#  ['nan', 'cake', 'fresh bread'],
#  ['nan', 'cake', 'fresh tuna'],
#  ['cake', 'frozen smoothie', 'mineral water'],
#  ['nan', 'cake', 'frozen smoothie'],
#  ['cake', 'frozen vegetables', 'mineral water'],
#  ['nan', 'cake', 'frozen vegetables'],
#  ['spaghetti', 'cake', 'frozen vegetables'],
#  ['cake', 'frozen vegetables', 'tomatoes'],
#  ['nan', 'cake', 'grated cheese'],
#  ['cake', 'green tea', 'mineral water'],
#  ['nan', 'cake', 'green tea'],
#  ['pancakes', 'cake', 'green tea'],
#  ['cake', 'ground beef', 'mineral water'],
#  ['nan', 'cake', 'ground beef'],
#  ['spaghetti', 'cake', 'ground beef'],
#  ['nan', 'cake', 'herb & pepper'],
#  ['nan', 'cake', 'honey'],
#  ['nan', 'cake', 'hot dogs'],
#  ['low fat yogurt', 'cake', 'nan'],
#  ['cake', 'milk', 'mineral water'],
#  ['nan', 'cake', 'milk'],
#  ['spaghetti', 'cake', 'milk'],
#  ['nan', 'cake', 'mineral water'],
#  ['olive oil', 'cake', 'mineral water'],
#  ['pancakes', 'cake', 'mineral water'],
#  ['cake', 'soup', 'mineral water'],
#  ['spaghetti', 'cake', 'mineral water'],
#  ['cake', 'mineral water', 'tomatoes'],
#  ['cake', 'whole wheat rice', 'mineral water'],
#  ['olive oil', 'nan', 'cake'],
#  ['pancakes', 'nan', 'cake'],
#  ['parmesan cheese', 'nan', 'cake'],
#  ['red wine', 'nan', 'cake'],
#  ['nan', 'cake', 'salmon'],
#  ['nan', 'cake', 'shrimp'],
#  ['nan', 'cake', 'soup'],
#  ['spaghetti', 'nan', 'cake'],
#  ['nan', 'cake', 'tomato juice'],
#  ['nan', 'cake', 'tomatoes'],
#  ['nan', 'cake', 'turkey'],
#  ['nan', 'cake', 'whole wheat pasta'],
#  ['nan', 'cake', 'whole wheat rice'],
#  ['olive oil', 'cake', 'spaghetti'],
#  ['pancakes', 'cake', 'spaghetti'],
#  ['spaghetti', 'cake', 'tomatoes'],
#  ['nan', 'chocolate', 'carrots'],
#  ['nan', 'green tea', 'carrots'],
#  ['nan', 'mineral water', 'carrots'],
#  ['spaghetti', 'nan', 'carrots'],
#  ['cereals', 'nan', 'chocolate'],
#  ['cereals', 'nan', 'eggs'],
#  ['cereals', 'nan', 'french fries'],
#  ['cereals', 'nan', 'frozen vegetables'],
#  ['cereals', 'nan', 'green tea'],
#  ['cereals', 'nan', 'ground beef'],
#  ['cereals', 'ground beef', 'spaghetti'],
#  ['cereals', 'nan', 'herb & pepper'],
#  ['cereals', 'milk', 'mineral water'],
#  ['cereals', 'nan', 'milk'],
#  ['cereals', 'nan', 'mineral water'],
#  ['cereals', 'spaghetti', 'mineral water'],
#  ['cereals', 'pancakes', 'nan'],
#  ['cereals', 'nan', 'shrimp'],
#  ['cereals', 'nan', 'spaghetti'],
#  ['champagne', 'nan', 'chocolate'],
#  ['champagne', 'nan', 'cookies'],
#  ['champagne', 'nan', 'eggs'],
#  ['champagne', 'escalope', 'nan'],
#  ['champagne', 'nan', 'french fries'],
#  ['champagne', 'nan', 'frozen smoothie'],
#  ['champagne', 'nan', 'frozen vegetables'],
#  ['champagne', 'nan', 'green tea'],
#  ['champagne', 'nan', 'ground beef'],
#  ['champagne', 'low fat yogurt', 'nan'],
#  ['champagne', 'nan', 'milk'],
#  ['champagne', 'nan', 'mineral water'],
#  ['champagne', 'pancakes', 'nan'],
#  ['champagne', 'nan', 'spaghetti'],
#  ['champagne', 'nan', 'whole wheat rice'],
#  ['eggs', 'chicken', 'chocolate'],
#  ['chicken', 'chocolate', 'french fries'],
#  ['green tea', 'chicken', 'chocolate'],
#  ['milk', 'chicken', 'chocolate'],
#  ['chicken', 'chocolate', 'mineral water'],
#  ['nan', 'chicken', 'chocolate'],
#  ['spaghetti', 'chicken', 'chocolate'],
#  ['cooking oil', 'nan', 'chicken'],
#  ['nan', 'cottage cheese', 'chicken'],
#  ['eggs', 'chicken', 'french fries'],
#  ['eggs', 'chicken', 'milk'],
#  ['eggs', 'chicken', 'mineral water'],
#  ['nan', 'eggs', 'chicken'],
#  ['spaghetti', 'eggs', 'chicken'],
#  ['escalope', 'nan', 'chicken'],
#  ['milk', 'chicken', 'french fries'],
#  ['chicken', 'mineral water', 'french fries'],
#  ['nan', 'chicken', 'french fries'],
#  ['spaghetti', 'chicken', 'french fries'],
#  ['nan', 'fresh bread', 'chicken'],
#  ['nan', 'chicken', 'frozen smoothie'],
#  ['chicken', 'frozen vegetables', 'mineral water'],
#  ['nan', 'chicken', 'frozen vegetables'],
#  ['spaghetti', 'chicken', 'frozen vegetables'],
#  ['nan', 'chicken', 'grated cheese'],
#  ['green tea', 'chicken', 'mineral water'],
#  ['nan', 'green tea', 'chicken'],
#  ['spaghetti', 'green tea', 'chicken'],
#  ['ground beef', 'chicken', 'milk'],
#  ['ground beef', 'chicken', 'mineral water'],
#  ['nan', 'ground beef', 'chicken'],
#  ['spaghetti', 'ground beef', 'chicken'],
#  ['nan', 'herb & pepper', 'chicken'],
#  ['nan', 'honey', 'chicken'],
#  ['nan', 'chicken', 'hot dogs'],
#  ['light cream', 'nan', 'chicken'],
#  ['low fat yogurt', 'nan', 'chicken'],
#  ['meatballs', 'nan', 'chicken'],
#  ['milk', 'chicken', 'mineral water'],
#  ['nan', 'milk', 'chicken'],
#  ['olive oil', 'milk', 'chicken'],
#  ['pancakes', 'milk', 'chicken'],
#  ['spaghetti', 'milk', 'chicken'],
#  ['nan', 'chicken', 'mineral water'],
#  ['olive oil', 'chicken', 'mineral water'],
#  ['pancakes', 'chicken', 'mineral water'],
#  ['soup', 'chicken', 'mineral water'],
#  ['spaghetti', 'chicken', 'mineral water'],
#  ['chicken', 'mineral water', 'tomatoes'],
#  ['olive oil', 'nan', 'chicken'],
#  ['pancakes', 'nan', 'chicken'],
#  ['nan', 'chicken', 'salmon'],
#  ['nan', 'shrimp', 'chicken'],
#  ['soup', 'nan', 'chicken'],
#  ['spaghetti', 'nan', 'chicken'],
#  ['nan', 'chicken', 'tomato juice'],
#  ['nan', 'chicken', 'tomatoes'],
#  ['nan', 'chicken', 'turkey'],
#  ['nan', 'whole wheat pasta', 'chicken'],
#  ['nan', 'whole wheat rice', 'chicken'],
#  ['olive oil', 'chicken', 'spaghetti'],
#  ['pancakes', 'chicken', 'spaghetti'],
#  ['french fries', 'chocolate', 'cookies'],
#  ['nan', 'chocolate', 'cookies'],
#  ['spaghetti', 'chocolate', 'cookies'],
#  ['cooking oil', 'eggs', 'chocolate'],
#  ['cooking oil', 'milk', 'chocolate'],
#  ['cooking oil', 'chocolate', 'mineral water'],
#  ['cooking oil', 'nan', 'chocolate'],
#  ['spaghetti', 'cooking oil', 'chocolate'],
#  ['nan', 'cottage cheese', 'chocolate'],
#  ['escalope', 'eggs', 'chocolate'],
#  ['eggs', 'chocolate', 'french fries'],
#  ['frozen vegetables', 'eggs', 'chocolate'],
#  ['green tea', 'eggs', 'chocolate'],
#  ['ground beef', 'eggs', 'chocolate'],
#  ['low fat yogurt', 'eggs', 'chocolate'],
#  ['milk', 'eggs', 'chocolate'],
#  ['eggs', 'chocolate', 'mineral water'],
#  ['nan', 'eggs', 'chocolate'],
#  ['olive oil', 'eggs', 'chocolate'],
#  ['pancakes', 'eggs', 'chocolate'],
#  ['shrimp', 'eggs', 'chocolate'],
#  ['spaghetti', 'eggs', 'chocolate'],
#  ['eggs', 'chocolate', 'turkey'],
#  ['nan', 'chocolate', 'energy bar'],
#  ['nan', 'chocolate', 'energy drink'],
#  ['escalope', 'chocolate', 'french fries'],
#  ['escalope', 'milk', 'chocolate'],
#  ['escalope', 'chocolate', 'mineral water'],
#  ['escalope', 'nan', 'chocolate'],
#  ['spaghetti', 'escalope', 'chocolate'],
#  ['frozen smoothie', 'chocolate', 'french fries'],
#  ['frozen vegetables', 'chocolate', 'french fries'],
#  ['grated cheese', 'chocolate', 'french fries'],
#  ['green tea', 'chocolate', 'french fries'],
#  ['ground beef', 'chocolate', 'french fries'],
#  ['low fat yogurt', 'chocolate', 'french fries'],
#  ['milk', 'chocolate', 'french fries'],
#  ['chocolate', 'mineral water', 'french fries'],
#  ['nan', 'chocolate', 'french fries'],
#  ['olive oil', 'chocolate', 'french fries'],
#  ['pancakes', 'chocolate', 'french fries'],
#  ['shrimp', 'chocolate', 'french fries'],
#  ['spaghetti', 'chocolate', 'french fries'],
#  ['tomatoes', 'chocolate', 'french fries'],
#  ['nan', 'chocolate', 'french wine'],
#  ['fresh bread', 'chocolate', 'mineral water'],
#  ['nan', 'fresh bread', 'chocolate'],
#  ['nan', 'fresh tuna', 'chocolate'],
#  ['fromage blanc', 'nan', 'chocolate'],
#  ['frozen smoothie', 'milk', 'chocolate'],
#  ['frozen smoothie', 'chocolate', 'mineral water'],
#  ['frozen smoothie', 'nan', 'chocolate'],
#  ['frozen smoothie', 'spaghetti', 'chocolate'],
#  ['frozen vegetables', 'green tea', 'chocolate'],
#  ['frozen vegetables', 'ground beef', 'chocolate'],
#  ['frozen vegetables', 'milk', 'chocolate'],
#  ['frozen vegetables', 'chocolate', 'mineral water'],
#  ['nan', 'frozen vegetables', 'chocolate'],
#  ['olive oil', 'frozen vegetables', 'chocolate'],
#  ['pancakes', 'frozen vegetables', 'chocolate'],
#  ['frozen vegetables', 'shrimp', 'chocolate'],
#  ['spaghetti', 'frozen vegetables', 'chocolate'],
#  ['frozen vegetables', 'chocolate', 'tomatoes'],
#  ['grated cheese', 'chocolate', 'mineral water'],
#  ['nan', 'grated cheese', 'chocolate'],
#  ['spaghetti', 'grated cheese', 'chocolate'],
#  ['green tea', 'chocolate', 'ground beef'],
#  ['green tea', 'milk', 'chocolate'],
#  ['green tea', 'chocolate', 'mineral water'],
#  ['nan', 'green tea', 'chocolate'],
#  ['pancakes', 'green tea', 'chocolate'],
#  ['spaghetti', 'green tea', 'chocolate'],
#  ['ground beef', 'herb & pepper', 'chocolate'],
#  ['ground beef', 'milk', 'chocolate'],
#  ['ground beef', 'chocolate', 'mineral water'],
#  ['nan', 'ground beef', 'chocolate'],
#  ['olive oil', 'ground beef', 'chocolate'],
#  ['pancakes', 'ground beef', 'chocolate'],
#  ['ground beef', 'shrimp', 'chocolate'],
#  ['spaghetti', 'ground beef', 'chocolate'],
#  ['ham', 'nan', 'chocolate'],
#  ['herb & pepper', 'chocolate', 'mineral water'],
#  ['nan', 'herb & pepper', 'chocolate'],
#  ['honey', 'chocolate', 'mineral water'],
#  ['nan', 'honey', 'chocolate'],
#  ['nan', 'hot dogs', 'chocolate'],
#  ['light cream', 'nan', 'chocolate'],
#  ['nan', 'light mayo', 'chocolate'],
#  ['low fat yogurt', 'milk', 'chocolate'],
#  ['low fat yogurt', 'chocolate', 'mineral water'],
#  ['low fat yogurt', 'nan', 'chocolate'],
#  ['spaghetti', 'low fat yogurt', 'chocolate'],
#  ['milk', 'chocolate', 'mineral water'],
#  ['nan', 'milk', 'chocolate'],
#  ['olive oil', 'milk', 'chocolate'],
#  ['pancakes', 'milk', 'chocolate'],
#  ['milk', 'shrimp', 'chocolate'],
#  ['milk', 'soup', 'chocolate'],
#  ['spaghetti', 'milk', 'chocolate'],
#  ['milk', 'chocolate', 'tomatoes'],
#  ['milk', 'chocolate', 'turkey'],
#  ['nan', 'chocolate', 'mineral water'],
#  ['olive oil', 'chocolate', 'mineral water'],
#  ['pancakes', 'chocolate', 'mineral water'],
#  ['salmon', 'chocolate', 'mineral water'],
#  ['shrimp', 'chocolate', 'mineral water'],
#  ['soup', 'chocolate', 'mineral water'],
#  ['spaghetti', 'chocolate', 'mineral water'],
#  ['chocolate', 'mineral water', 'tomatoes'],
#  ['chocolate', 'mineral water', 'turkey'],
#  ['whole wheat rice', 'chocolate', 'mineral water'],
#  ['nan', 'chocolate', 'mint'],
#  ['muffins', 'nan', 'chocolate'],
#  ['mushroom cream sauce', 'nan', 'chocolate'],
#  ['nan', 'chocolate', 'oil'],
#  ['olive oil', 'nan', 'chocolate'],
#  ['pancakes', 'nan', 'chocolate'],
#  ['parmesan cheese', 'nan', 'chocolate'],
#  ['nan', 'chocolate', 'pepper'],
#  ['nan', 'protein bar', 'chocolate'],
#  ['red wine', 'nan', 'chocolate'],
#  ['nan', 'rice', 'chocolate'],
#  ['nan', 'salmon', 'chocolate'],
#  ['nan', 'shrimp', 'chocolate'],
#  ['nan', 'soup', 'chocolate'],
#  ['spaghetti', 'nan', 'chocolate'],
#  ['nan', 'strawberries', 'chocolate'],
#  ['nan', 'tomato juice', 'chocolate'],
#  ['nan', 'tomato sauce', 'chocolate'],
#  ['nan', 'chocolate', 'tomatoes'],
#  ['nan', 'chocolate', 'turkey'],
#  ['nan', 'vegetables mix', 'chocolate'],
#  ['nan', 'chocolate', 'white wine'],
#  ['nan', 'whole wheat pasta', 'chocolate'],
#  ['nan', 'whole wheat rice', 'chocolate'],
#  ['nan', 'chocolate', 'yogurt cake'],
#  ['olive oil', 'pancakes', 'chocolate'],
#  ['olive oil', 'spaghetti', 'chocolate'],
#  ['pancakes', 'spaghetti', 'chocolate'],
#  ['spaghetti', 'salmon', 'chocolate'],
#  ['spaghetti', 'shrimp', 'chocolate'],
#  ['spaghetti', 'soup', 'chocolate'],
#  ['spaghetti', 'chocolate', 'tomatoes'],
#  ['spaghetti', 'chocolate', 'turkey'],
#  ['spaghetti', 'whole wheat rice', 'chocolate'],
#  ['nan', 'cider', 'eggs'],
#  ['nan', 'cider', 'milk'],
#  ['nan', 'eggs', 'cookies'],
#  ['green tea', 'french fries', 'cookies'],
#  ['nan', 'french fries', 'cookies'],
#  ['nan', 'frozen smoothie', 'cookies'],
#  ['nan', 'green tea', 'cookies'],
#  ['nan', 'ground beef', 'cookies'],
#  ['low fat yogurt', 'nan', 'cookies'],
#  ['nan', 'milk', 'cookies'],
#  ['nan', 'mineral water', 'cookies'],
#  ['pancakes', 'nan', 'cookies'],
#  ['nan', 'shrimp', 'cookies'],
#  ['spaghetti', 'nan', 'cookies'],
#  ['nan', 'whole wheat rice', 'cookies'],
#  ['cooking oil', 'milk', 'eggs'],
#  ['cooking oil', 'eggs', 'mineral water'],
#  ['cooking oil', 'nan', 'eggs'],
#  ['spaghetti', 'cooking oil', 'eggs'],
#  ['cooking oil', 'nan', 'escalope'],
#  ['cooking oil', 'nan', 'french fries'],
#  ['cooking oil', 'nan', 'frozen smoothie'],
#  ['cooking oil', 'nan', 'frozen vegetables'],
#  ['cooking oil', 'nan', 'grated cheese'],
#  ['cooking oil', 'green tea', 'mineral water'],
#  ['cooking oil', 'nan', 'green tea'],
#  ['cooking oil', 'ground beef', 'mineral water'],
#  ['cooking oil', 'nan', 'ground beef'],
#  ['spaghetti', 'cooking oil', 'ground beef'],
#  ['cooking oil', 'nan', 'herb & pepper'],
#  ['cooking oil', 'nan', 'honey'],
#  ['cooking oil', 'low fat yogurt', 'nan'],
#  ['cooking oil', 'milk', 'mineral water'],
#  ['cooking oil', 'nan', 'milk'],
#  ['spaghetti', 'cooking oil', 'milk'],
#  ['cooking oil', 'nan', 'mineral water'],
#  ['pancakes', 'cooking oil', 'mineral water'],
#  ['spaghetti', 'cooking oil', 'mineral water'],
#  ['olive oil', 'cooking oil', 'nan'],
#  ['pancakes', 'cooking oil', 'nan'],
#  ['cooking oil', 'nan', 'salmon'],
#  ['cooking oil', 'nan', 'shrimp'],
#  ['cooking oil', 'nan', 'soup'],
#  ['spaghetti', 'cooking oil', 'nan'],
#  ['cooking oil', 'nan', 'tomatoes'],
#  ['cooking oil', 'nan', 'turkey'],
#  ['cooking oil', 'nan', 'whole wheat rice'],
#  ['nan', 'eggs', 'cottage cheese'],
#  ['nan', 'cottage cheese', 'french fries'],
#  ['nan', 'cottage cheese', 'frozen smoothie'],
#  ['nan', 'cottage cheese', 'frozen vegetables'],
#  ['nan', 'green tea', 'cottage cheese'],
#  ['nan', 'ground beef', 'cottage cheese'],
#  ['nan', 'milk', 'cottage cheese'],
#  ['nan', 'cottage cheese', 'mineral water'],
#  ['spaghetti', 'cottage cheese', 'mineral water'],
#  ['olive oil', 'nan', 'cottage cheese'],
#  ['pancakes', 'nan', 'cottage cheese'],
#  ['spaghetti', 'nan', 'cottage cheese'],
#  ['nan', 'eggs', 'eggplant'],
#  ['nan', 'eggplant', 'mineral water'],
#  ['spaghetti', 'nan', 'eggplant'],
#  ['nan', 'eggs', 'energy bar'],
#  ['nan', 'eggs', 'energy drink'],
#  ['escalope', 'eggs', 'mineral water'],
#  ['escalope', 'nan', 'eggs'],
#  ['eggs', 'frozen vegetables', 'french fries'],
#  ['green tea', 'eggs', 'french fries'],
#  ['ground beef', 'eggs', 'french fries'],
#  ['low fat yogurt', 'eggs', 'french fries'],
#  ['milk', 'eggs', 'french fries'],
#  ['eggs', 'mineral water', 'french fries'],
#  ['nan', 'eggs', 'french fries'],
#  ['pancakes', 'eggs', 'french fries'],
#  ['spaghetti', 'eggs', 'french fries'],
#  ['tomatoes', 'eggs', 'french fries'],
#  ['eggs', 'turkey', 'french fries'],
#  ['nan', 'eggs', 'french wine'],
#  ['fresh bread', 'eggs', 'mineral water'],
#  ['nan', 'fresh bread', 'eggs'],
#  ['nan', 'eggs', 'fresh tuna'],
#  ['nan', 'eggs', 'fromage blanc'],
#  ['eggs', 'frozen smoothie', 'mineral water'],
#  ['nan', 'eggs', 'frozen smoothie'],
#  ['green tea', 'eggs', 'frozen vegetables'],
#  ['ground beef', 'eggs', 'frozen vegetables'],
#  ['low fat yogurt', 'eggs', 'frozen vegetables'],
#  ['milk', 'eggs', 'frozen vegetables'],
#  ['eggs', 'frozen vegetables', 'mineral water'],
#  ['nan', 'eggs', 'frozen vegetables'],
#  ['pancakes', 'eggs', 'frozen vegetables'],
#  ['shrimp', 'eggs', 'frozen vegetables'],
#  ['spaghetti', 'eggs', 'frozen vegetables'],
#  ['eggs', 'frozen vegetables', 'tomatoes'],
#  ['eggs', 'grated cheese', 'mineral water'],
#  ['nan', 'eggs', 'grated cheese'],
#  ['spaghetti', 'eggs', 'grated cheese'],
#  ['green tea', 'eggs', 'milk'],
#  ['green tea', 'eggs', 'mineral water'],
#  ['nan', 'green tea', 'eggs'],
#  ['pancakes', 'green tea', 'eggs'],
#  ['spaghetti', 'green tea', 'eggs'],
#  ['green tea', 'eggs', 'turkey'],
#  ['herb & pepper', 'ground beef', 'eggs'],
#  ['ground beef', 'eggs', 'milk'],
#  ['ground beef', 'eggs', 'mineral water'],
#  ['nan', 'ground beef', 'eggs'],
#  ['spaghetti', 'ground beef', 'eggs'],
#  ['ham', 'nan', 'eggs'],
#  ['herb & pepper', 'milk', 'eggs'],
#  ['herb & pepper', 'eggs', 'mineral water'],
#  ['nan', 'herb & pepper', 'eggs'],
#  ['spaghetti', 'herb & pepper', 'eggs'],
#  ['nan', 'honey', 'eggs'],
#  ['nan', 'eggs', 'hot dogs'],
#  ['light cream', 'nan', 'eggs'],
#  ['nan', 'eggs', 'light mayo'],
#  ['low fat yogurt', 'milk', 'eggs'],
#  ['low fat yogurt', 'eggs', 'mineral water'],
#  ['low fat yogurt', 'nan', 'eggs'],
#  ['spaghetti', 'low fat yogurt', 'eggs'],
#  ...]
